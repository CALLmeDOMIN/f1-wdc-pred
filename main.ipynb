# %%
import fastf1
import pandas as pd

# %%
session = fastf1.get_session(2023, 5, 'R')

session.load()
# Out:
# req         WARNING 	DEFAULT CACHE ENABLED! (384.62 MB) C:\Users\domin\AppData\Local\Temp\fastf1
# core           INFO 	Loading data for Miami Grand Prix - Race [v3.5.3]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['1', '11', '14', '63', '55', '44', '16', '10', '31', '20', '22', '18', '77', '23', '27', '24', '4', '21', '81', '2']

# %%
session.event["OfficialEventName"]
# Out:
# 'FORMULA 1 CRYPTO.COM MIAMI GRAND PRIX 2023'

# %%
session.results
# Out:
#    DriverNumber BroadcastName Abbreviation         DriverId         TeamName  \
# 1             1  M VERSTAPPEN          VER   max_verstappen  Red Bull Racing
# 11           11       S PEREZ          PER            perez  Red Bull Racing
# 14           14      F ALONSO          ALO           alonso     Aston Martin
# 63           63     G RUSSELL          RUS          russell         Mercedes
# 55           55       C SAINZ          SAI            sainz          Ferrari
# 44           44    L HAMILTON          HAM         hamilton         Mercedes
# 16           16     C LECLERC          LEC          leclerc          Ferrari
# 10           10       P GASLY          GAS            gasly           Alpine
# 31           31        E OCON          OCO             ocon           Alpine
# 20           20   K MAGNUSSEN          MAG  kevin_magnussen     Haas F1 Team
# 22           22     Y TSUNODA          TSU          tsunoda       AlphaTauri
# 18           18      L STROLL          STR           stroll     Aston Martin
# 77           77      V BOTTAS          BOT           bottas       Alfa Romeo
# 23           23       A ALBON          ALB            albon         Williams
# 27           27  N HULKENBERG          HUL       hulkenberg     Haas F1 Team
# 24           24        G ZHOU          ZHO             zhou       Alfa Romeo
# 4             4      L NORRIS          NOR           norris          McLaren
# 21           21    N DE VRIES          DEV         de_vries       AlphaTauri
# 81           81     O PIASTRI          PIA          piastri          McLaren
# 2             2    L SARGEANT          SAR         sargeant         Williams
#
#    TeamColor        TeamId  FirstName    LastName         FullName  ...  \
# 1     3671C6      red_bull        Max  Verstappen   Max Verstappen  ...
# 11    3671C6      red_bull     Sergio       Perez     Sergio Perez  ...
# 14    358C75  aston_martin   Fernando      Alonso  Fernando Alonso  ...
# 63    6CD3BF      mercedes     George     Russell   George Russell  ...
# 55    F91536       ferrari     Carlos       Sainz     Carlos Sainz  ...
# 44    6CD3BF      mercedes      Lewis    Hamilton   Lewis Hamilton  ...
# 16    F91536       ferrari    Charles     Leclerc  Charles Leclerc  ...
# 10    2293D1        alpine     Pierre       Gasly     Pierre Gasly  ...
# 31    2293D1        alpine    Esteban        Ocon     Esteban Ocon  ...
# 20    B6BABD          haas      Kevin   Magnussen  Kevin Magnussen  ...
# 22    5E8FAA    alphatauri       Yuki     Tsunoda     Yuki Tsunoda  ...
# 18    358C75  aston_martin      Lance      Stroll     Lance Stroll  ...
# 77    C92D4B          alfa   Valtteri      Bottas  Valtteri Bottas  ...
# 23    37BEDD      williams  Alexander       Albon  Alexander Albon  ...
# 27    B6BABD          haas       Nico  Hulkenberg  Nico Hulkenberg  ...
# 24    C92D4B          alfa     Guanyu        Zhou      Guanyu Zhou  ...
# 4     F58020       mclaren      Lando      Norris     Lando Norris  ...
# 21    5E8FAA    alphatauri       Nyck    De Vries    Nyck De Vries  ...
# 81    F58020       mclaren      Oscar     Piastri    Oscar Piastri  ...
# 2     37BEDD      williams      Logan    Sargeant   Logan Sargeant  ...
#
#    CountryCode Position  ClassifiedPosition GridPosition  Q1  Q2  Q3  \
# 1          NED      1.0                   1          9.0 NaT NaT NaT
# 11         MEX      2.0                   2          1.0 NaT NaT NaT
# 14         ESP      3.0                   3          2.0 NaT NaT NaT
# 63         GBR      4.0                   4          6.0 NaT NaT NaT
# 55         ESP      5.0                   5          3.0 NaT NaT NaT
# 44         GBR      6.0                   6         13.0 NaT NaT NaT
# 16         MON      7.0                   7          7.0 NaT NaT NaT
# 10         FRA      8.0                   8          5.0 NaT NaT NaT
# 31         FRA      9.0                   9          8.0 NaT NaT NaT
# 20         DEN     10.0                  10          4.0 NaT NaT NaT
# 22         JPN     11.0                  11         17.0 NaT NaT NaT
# 18         CAN     12.0                  12         18.0 NaT NaT NaT
# 77         FIN     13.0                  13         10.0 NaT NaT NaT
# 23         THA     14.0                  14         11.0 NaT NaT NaT
# 27         GER     15.0                  15         12.0 NaT NaT NaT
# 24         CHN     16.0                  16         14.0 NaT NaT NaT
# 4          GBR     17.0                  17         16.0 NaT NaT NaT
# 21         NED     18.0                  18         15.0 NaT NaT NaT
# 81         AUS     19.0                  19         19.0 NaT NaT NaT
# 2          USA     20.0                  20         20.0 NaT NaT NaT
#
#                      Time    Status Points
# 1  0 days 01:27:38.241000  Finished   26.0
# 11 0 days 00:00:05.384000  Finished   18.0
# 14 0 days 00:00:26.305000  Finished   15.0
# 63 0 days 00:00:33.229000  Finished   12.0
# 55 0 days 00:00:42.511000  Finished   10.0
# 44 0 days 00:00:51.249000  Finished    8.0
# 16 0 days 00:00:52.988000  Finished    6.0
# 10 0 days 00:00:55.670000  Finished    4.0
# 31 0 days 00:00:58.123000  Finished    2.0
# 20 0 days 00:01:02.945000  Finished    1.0
# 22 0 days 00:01:04.309000  Finished    0.0
# 18 0 days 00:01:04.754000  Finished    0.0
# 77 0 days 00:01:11.637000  Finished    0.0
# 23 0 days 00:01:12.861000  Finished    0.0
# 27 0 days 00:01:14.950000  Finished    0.0
# 24 0 days 00:01:18.440000  Finished    0.0
# 4  0 days 00:01:27.717000  Finished    0.0
# 21 0 days 00:01:28.949000  Finished    0.0
# 81 0 days 00:00:20.510000    Lapped    0.0
# 2  0 days 00:00:34.388000    Lapped    0.0
#
# [20 rows x 21 columns]

# %%
session.results.dtypes
# Out:
# DriverNumber                   object
# BroadcastName                  object
# Abbreviation                   object
# DriverId                       object
# TeamName                       object
# TeamColor                      object
# TeamId                         object
# FirstName                      object
# LastName                       object
# FullName                       object
# HeadshotUrl                    object
# CountryCode                    object
# Position                      float64
# ClassifiedPosition             object
# GridPosition                  float64
# Q1                    timedelta64[ns]
# Q2                    timedelta64[ns]
# Q3                    timedelta64[ns]
# Time                  timedelta64[ns]
# Status                         object
# Points                        float64
# dtype: object

# %%
session.laps
# Out:
#                       Time Driver DriverNumber                LapTime  \
# 0   0 days 01:04:01.390000    GAS           10 0 days 00:01:39.330000
# 1   0 days 01:05:34.204000    GAS           10 0 days 00:01:32.814000
# 2   0 days 01:07:05.737000    GAS           10 0 days 00:01:31.533000
# 3   0 days 01:08:37.176000    GAS           10 0 days 00:01:31.439000
# 4   0 days 01:10:08.543000    GAS           10 0 days 00:01:31.367000
# ..                     ...    ...          ...                    ...
# 995 0 days 01:48:13.815000    GIO           99 0 days 00:01:29.775000
# 996 0 days 01:49:43.320000    GIO           99 0 days 00:01:29.505000
# 997 0 days 01:51:12.916000    GIO           99 0 days 00:01:29.596000
# 998 0 days 01:52:42.358000    GIO           99 0 days 00:01:29.442000
# 999 0 days 01:54:12.993000    GIO           99                    NaT
#
#      LapNumber  Stint PitOutTime PitInTime            Sector1Time  \
# 0          1.0    1.0        NaT       NaT                    NaT
# 1          2.0    1.0        NaT       NaT 0 days 00:00:18.899000
# 2          3.0    1.0        NaT       NaT 0 days 00:00:18.581000
# 3          4.0    1.0        NaT       NaT 0 days 00:00:18.507000
# 4          5.0    1.0        NaT       NaT 0 days 00:00:18.400000
# ..         ...    ...        ...       ...                    ...
# 995       30.0    2.0        NaT       NaT 0 days 00:00:18.146000
# 996       31.0    2.0        NaT       NaT 0 days 00:00:18.093000
# 997       32.0    2.0        NaT       NaT 0 days 00:00:18.098000
# 998       33.0    2.0        NaT       NaT 0 days 00:00:17.989000
# 999       34.0    2.0        NaT       NaT                    NaT
#
#                Sector2Time  ... FreshTyre               Team  \
# 0   0 days 00:00:39.238000  ...      True         AlphaTauri
# 1   0 days 00:00:38.961000  ...      True         AlphaTauri
# 2   0 days 00:00:38.489000  ...      True         AlphaTauri
# 3   0 days 00:00:38.592000  ...      True         AlphaTauri
# 4   0 days 00:00:38.837000  ...      True         AlphaTauri
# ..                     ...  ...       ...                ...
# 995 0 days 00:00:38.496000  ...      True  Alfa Romeo Racing
# 996 0 days 00:00:38.532000  ...      True  Alfa Romeo Racing
# 997 0 days 00:00:38.526000  ...      True  Alfa Romeo Racing
# 998 0 days 00:00:38.608000  ...      True  Alfa Romeo Racing
# 999                    NaT  ...      True  Alfa Romeo Racing
#
#               LapStartTime            LapStartDate  TrackStatus  Position  \
# 0   0 days 01:02:21.871000 2021-12-12 13:03:21.881            1      12.0
# 1   0 days 01:04:01.390000 2021-12-12 13:05:01.400            1      12.0
# 2   0 days 01:05:34.204000 2021-12-12 13:06:34.214            1      12.0
# 3   0 days 01:07:05.737000 2021-12-12 13:08:05.747            1      12.0
# 4   0 days 01:08:37.176000 2021-12-12 13:09:37.186            1      12.0
# ..                     ...                     ...          ...       ...
# 995 0 days 01:46:44.040000 2021-12-12 13:47:44.050            1      13.0
# 996 0 days 01:48:13.815000 2021-12-12 13:49:13.825            1      13.0
# 997 0 days 01:49:43.320000 2021-12-12 13:50:43.330            1      13.0
# 998 0 days 01:51:12.916000 2021-12-12 13:52:12.926            1      13.0
# 999 0 days 01:52:42.358000                     NaT            1       NaN
#
#      Deleted  DeletedReason FastF1Generated IsAccurate
# 0      False                          False      False
# 1      False                          False       True
# 2      False                          False       True
# 3      False                          False       True
# 4      False                          False       True
# ..       ...            ...             ...        ...
# 995    False                          False       True
# 996    False                          False       True
# 997    False                          False       True
# 998    False                          False       True
# 999    False            NaN            True      False
#
# [1000 rows x 31 columns]

# %%
driver_stats = []


for result in session.results.iterrows():
    driver = result[1]["Abbreviation"]
    
    avg_lap_time = session.laps.pick_drivers(driver)["LapTime"].mean()
    
    driver_stats.append({
        "Driver": result[1]["Abbreviation"],
        "TeamId": result[1]["TeamId"],
        "FinishPosition": result[1]["Position"],
        "PositionsGained": result[1]["Position"] - result[1]["GridPosition"],
        "PointsGained": result[1]["Points"],
        "AvgLapTime": avg_lap_time,
    })
    
driver_stats_df = pd.DataFrame(driver_stats)

driver_stats_df
# Out:
#    Driver        TeamId  FinishPosition  PositionsGained  PointsGained  \
# 0     PIA       mclaren             1.0             -3.0          25.0
# 1     NOR       mclaren             2.0              0.0          18.0
# 2     RUS      mercedes             3.0             -2.0          15.0
# 3     VER      red_bull             4.0              3.0          12.0
# 4     ALB      williams             5.0             -2.0          10.0
# 5     ANT      mercedes             6.0              3.0           8.0
# 6     LEC       ferrari             7.0             -1.0           6.0
# 7     HAM       ferrari             8.0             -4.0           4.0
# 8     SAI      williams             9.0              3.0           2.0
# 9     TSU      red_bull            10.0              0.0           1.0
# 10    HAD            rb            11.0              0.0           0.0
# 11    OCO          haas            12.0              3.0           0.0
# 12    GAS        alpine            13.0             -7.0           0.0
# 13    HUL        sauber            14.0             -2.0           0.0
# 14    ALO  aston_martin            15.0             -2.0           0.0
# 15    STR  aston_martin            16.0             -2.0           0.0
# 16    LAW            rb            17.0              2.0           0.0
# 17    BOR        sauber            18.0              5.0           0.0
# 18    BEA          haas            19.0              0.0           0.0
# 19    DOO        alpine            20.0              6.0           0.0
#
#                   AvgLapTime
# 0  0 days 00:01:33.536614035
# 1  0 days 00:01:33.617842105
# 2  0 days 00:01:34.197035087
# 3  0 days 00:01:34.237596491
# 4  0 days 00:01:34.379894736
# 5  0 days 00:01:34.510333333
# 6  0 days 00:01:34.537245614
# 7  0 days 00:01:34.592508771
# 8  0 days 00:01:34.599368421
# 9  0 days 00:01:34.754754385
# 10 0 days 00:01:34.845421052
# 11 0 days 00:01:34.975315789
# 12 0 days 00:01:35.123368421
# 13 0 days 00:01:35.227535714
# 14 0 days 00:01:35.581535714
# 15 0 days 00:01:35.656232142
# 16 0 days 00:01:38.514194444
# 17    0 days 00:01:38.115300
# 18 0 days 00:01:35.954555555
# 19                       NaT

# %%
driver_stats_df = driver_stats_df.dropna()

driver_stats_df
# Out:
#    Driver        TeamId  FinishPosition  PositionsGained  PointsGained  \
# 0     VER      red_bull             1.0              0.0          26.0
# 1     HAM      mercedes             2.0              0.0          18.0
# 2     SAI       ferrari             3.0             -2.0          15.0
# 3     TSU    alphatauri             4.0             -4.0          12.0
# 4     GAS    alphatauri             5.0             -7.0          10.0
# 5     BOT      mercedes             6.0              0.0           8.0
# 6     NOR       mclaren             7.0              4.0           6.0
# 7     ALO        alpine             8.0             -3.0           4.0
# 8     OCO        alpine             9.0              0.0           2.0
# 9     LEC       ferrari            10.0              3.0           1.0
# 10    VET  aston_martin            11.0             -4.0           0.0
# 11    RIC       mclaren            12.0              2.0           0.0
# 12    STR  aston_martin            13.0              0.0           0.0
# 13    MSC          haas            14.0             -5.0           0.0
# 14    PER      red_bull            15.0             11.0           0.0
# 15    LAT      williams            16.0              0.0           0.0
# 16    GIO          alfa            17.0              3.0           0.0
# 17    RUS      williams            18.0              1.0           0.0
# 18    RAI          alfa            19.0              1.0           0.0
#
#                   AvgLapTime
# 0  0 days 00:01:32.401929824
# 1  0 days 00:01:32.412596491
# 2  0 days 00:01:33.491689655
# 3  0 days 00:01:33.500637931
# 4  0 days 00:01:33.515103448
# 5  0 days 00:01:33.531172413
# 6  0 days 00:01:33.410614035
# 7  0 days 00:01:33.456719298
# 8  0 days 00:01:33.505736842
# 9  0 days 00:01:33.538859649
# 10 0 days 00:01:33.585052631
# 11    0 days 00:01:34.114250
# 12 0 days 00:01:35.181175438
# 13 0 days 00:01:35.192052631
# 14 0 days 00:01:31.864927272
# 15    0 days 00:01:32.309820
# 16 0 days 00:01:31.524181818
# 17    0 days 00:01:32.183720
# 18    0 days 00:01:34.544440
